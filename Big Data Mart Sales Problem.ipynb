# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
train=pd.read_csv(r"C:\Users\VISHAL\Downloads\bigdatamart_Train.csv")
test=pd.read_csv(r"C:\Users\VISHAL\Downloads\bigdatamart_Test.csv")

# %%
train
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# ...                     ...       ...               ...
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998         NaN               Tier 3
# 4                          1987        High               Tier 3
# ...                         ...         ...                  ...
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 1     Supermarket Type2           443.4228
# 2     Supermarket Type1          2097.2700
# 3         Grocery Store           732.3800
# 4     Supermarket Type1           994.7052
# ...                 ...                ...
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700
#
# [8523 rows x 12 columns]

# %%
test
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# 1                  Dairy   87.3198            OUT017
# 2                 Others  241.7538            OUT010
# 3            Snack Foods  155.0340            OUT017
# 4                  Dairy  234.2300            OUT027
# ...                  ...       ...               ...
# 5676         Snack Foods  141.3154            OUT046
# 5677       Starchy Foods  169.1448            OUT018
# 5678  Health and Hygiene  118.7440            OUT045
# 5679              Canned  214.6218            OUT017
# 5680              Canned   79.7960            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2007         NaN               Tier 2
# 2                          1998         NaN               Tier 3
# 3                          2007         NaN               Tier 2
# 4                          1985      Medium               Tier 3
# ...                         ...         ...                  ...
# 5676                       1997       Small               Tier 1
# 5677                       2009      Medium               Tier 3
# 5678                       2002         NaN               Tier 2
# 5679                       2007         NaN               Tier 2
# 5680                       2002         NaN               Tier 2
#
#             Outlet_Type
# 0     Supermarket Type1
# 1     Supermarket Type1
# 2         Grocery Store
# 3     Supermarket Type1
# 4     Supermarket Type3
# ...                 ...
# 5676  Supermarket Type1
# 5677  Supermarket Type2
# 5678  Supermarket Type1
# 5679  Supermarket Type1
# 5680  Supermarket Type1
#
# [5681 rows x 11 columns]

# %%
print(train.shape)
print(test.shape)
# Out:
# (8523, 12)
# (5681, 11)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            5681 non-null   object
#  1   Item_Weight                4705 non-null   float64
#  2   Item_Fat_Content           5681 non-null   object
#  3   Item_Visibility            5681 non-null   float64
#  4   Item_Type                  5681 non-null   object
#  5   Item_MRP                   5681 non-null   float64
#  6   Outlet_Identifier          5681 non-null   object
#  7   Outlet_Establishment_Year  5681 non-null   int64
#  8   Outlet_Size                4075 non-null   object
#  9   Outlet_Location_Type       5681 non-null   object
#  10  Outlet_Type                5681 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 488.3+ KB

# %%
train.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
train.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
test.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year
# count  4705.000000      5681.000000  5681.000000                5681.000000
# mean     12.695633         0.065684   141.023273                1997.828903
# std       4.664849         0.051252    61.809091                   8.372256
# min       4.555000         0.000000    31.990000                1985.000000
# 25%       8.645000         0.027047    94.412000                1987.000000
# 50%      12.500000         0.054154   141.415400                1999.000000
# 75%      16.700000         0.093463   186.026600                2004.000000
# max      21.350000         0.323637   266.588400                2009.000000

# %%
sns.distplot(train['Item_Weight'])
# Out:
# <AxesSubplot:xlabel='Item_Weight', ylabel='Density'>

# %%
train['Item_Weight'].value_counts()
# Out:
# 12.150    86
# 17.600    82
# 13.650    77
# 11.800    76
# 15.100    68
#           ..
# 7.275      2
# 7.685      1
# 9.420      1
# 6.520      1
# 5.400      1
# Name: Item_Weight, Length: 415, dtype: int64

# %%
train['Item_Weight'].mean()
# Out:
# 12.857645184136183

# %%
train['Item_Weight'].fillna((train['Item_Weight'].mean()), inplace=True)

# %%
train.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
train['Outlet_Size'].value_counts()
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
train['Outlet_Type'].value_counts()
# Out:
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64

# %%
train.loc[train['Outlet_Type'] == 'Grocery Store']
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3              FDX07    19.200000          Regular         0.000000
# 23             FDC37    12.857645          Low Fat         0.057557
# 28             FDE51     5.925000          Regular         0.161467
# 29             FDC14    12.857645          Regular         0.072222
# 30             FDV38    19.250000          Low Fat         0.170349
# ...              ...          ...              ...              ...
# 8473           DRI47    14.700000          Low Fat         0.035016
# 8480           FDQ58    12.857645          Low Fat         0.000000
# 8486           FDR20    20.000000          Regular         0.000000
# 8490           FDU44    12.857645          Regular         0.102296
# 8509           FDG45     8.100000          Low Fat         0.214306
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 3     Fruits and Vegetables  182.0950            OUT010
# 23             Baking Goods  107.6938            OUT019
# 28                    Dairy   45.5086            OUT010
# 29                   Canned   43.6454            OUT019
# 30                    Dairy   55.7956            OUT010
# ...                     ...       ...               ...
# 8473            Hard Drinks  144.3128            OUT010
# 8480            Snack Foods  154.5340            OUT019
# 8486  Fruits and Vegetables   46.4744            OUT010
# 8490  Fruits and Vegetables  162.3552            OUT019
# 8509  Fruits and Vegetables  213.9902            OUT010
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 3                          1998         NaN               Tier 3
# 23                         1985       Small               Tier 1
# 28                         1998         NaN               Tier 3
# 29                         1985       Small               Tier 1
# 30                         1998         NaN               Tier 3
# ...                         ...         ...                  ...
# 8473                       1998         NaN               Tier 3
# 8480                       1985       Small               Tier 1
# 8486                       1998         NaN               Tier 3
# 8490                       1985       Small               Tier 1
# 8509                       1998         NaN               Tier 3
#
#         Outlet_Type  Item_Outlet_Sales
# 3     Grocery Store           732.3800
# 23    Grocery Store           214.3876
# 28    Grocery Store           178.4344
# 29    Grocery Store           125.8362
# 30    Grocery Store           163.7868
# ...             ...                ...
# 8473  Grocery Store           431.4384
# 8480  Grocery Store           459.4020
# 8486  Grocery Store            45.2744
# 8490  Grocery Store           487.3656
# 8509  Grocery Store           424.7804
#
# [1083 rows x 12 columns]

# %%
train.loc[train['Outlet_Type']=='Grocery Store','Outlet_Size'] = 'Small'

# %%
train['Outlet_Size'].value_counts()
# Out:
# Small     2943
# Medium    2793
# High       932
# Name: Outlet_Size, dtype: int64

# %%
train.loc[train['Outlet_Type'] == 'Supermarket Type1']
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 2              FDN15       17.500          Low Fat         0.016760
# 4              NCD19        8.930          Low Fat         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 8              FDH17       16.200          Regular         0.016687
# ...              ...          ...              ...              ...
# 8517           FDF53       20.750              reg         0.083607
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 2                   Meat  141.6180            OUT049
# 4              Household   53.8614            OUT013
# 6            Snack Foods   57.6588            OUT013
# 8           Frozen Foods   96.9726            OUT045
# ...                  ...       ...               ...
# 8517        Frozen Foods  178.8318            OUT046
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 2                          1999      Medium               Tier 1
# 4                          1987        High               Tier 3
# 6                          1987        High               Tier 3
# 8                          2002         NaN               Tier 2
# ...                         ...         ...                  ...
# 8517                       1997       Small               Tier 1
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# 8520                       2004       Small               Tier 2
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 2     Supermarket Type1          2097.2700
# 4     Supermarket Type1           994.7052
# 6     Supermarket Type1           343.5528
# 8     Supermarket Type1          1076.5986
# ...                 ...                ...
# 8517  Supermarket Type1          3608.6360
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8522  Supermarket Type1           765.6700
#
# [5577 rows x 12 columns]

# %%
train.loc[train['Outlet_Type'] == 'Supermarket Type2']
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1              DRC01        5.920          Regular         0.019278
# 5              FDP36       10.395          Regular         0.000000
# 16             NCB42       11.800          Low Fat         0.008596
# 31             NCS17       18.600          Low Fat         0.080829
# 32             FDP33       18.700          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8506           DRF37       17.250          Low Fat         0.084676
# 8511           FDF05       17.500          Low Fat         0.026980
# 8515           FDH24       20.700          Low Fat         0.021518
# 8516           NCJ19       18.600          Low Fat         0.118661
# 8521           FDN46        7.210          Regular         0.145221
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 1            Soft Drinks   48.2692            OUT018
# 5           Baking Goods   51.4008            OUT018
# 16    Health and Hygiene  115.3492            OUT018
# 31    Health and Hygiene   96.4436            OUT018
# 32           Snack Foods  256.6672            OUT018
# ...                  ...       ...               ...
# 8506         Soft Drinks  263.1910            OUT018
# 8511        Frozen Foods  262.5910            OUT018
# 8515        Baking Goods  157.5288            OUT018
# 8516              Others   58.7588            OUT018
# 8521         Snack Foods  103.1332            OUT018
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 1                          2009      Medium               Tier 3
# 5                          2009      Medium               Tier 3
# 16                         2009      Medium               Tier 3
# 31                         2009      Medium               Tier 3
# 32                         2009      Medium               Tier 3
# ...                         ...         ...                  ...
# 8506                       2009      Medium               Tier 3
# 8511                       2009      Medium               Tier 3
# 8515                       2009      Medium               Tier 3
# 8516                       2009      Medium               Tier 3
# 8521                       2009      Medium               Tier 3
#
#             Outlet_Type  Item_Outlet_Sales
# 1     Supermarket Type2           443.4228
# 5     Supermarket Type2           556.6088
# 16    Supermarket Type2          1621.8888
# 31    Supermarket Type2          2741.7644
# 32    Supermarket Type2          3068.0064
# ...                 ...                ...
# 8506  Supermarket Type2          3944.8650
# 8511  Supermarket Type2          4207.8560
# 8515  Supermarket Type2          1571.2880
# 8516  Supermarket Type2           858.8820
# 8521  Supermarket Type2          1845.5976
#
# [928 rows x 12 columns]

# %%
SM1=pd.DataFrame(data=(train.loc[train['Outlet_Type'] == 'Supermarket Type1']))

# %%
SM1
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 2              FDN15       17.500          Low Fat         0.016760
# 4              NCD19        8.930          Low Fat         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 8              FDH17       16.200          Regular         0.016687
# ...              ...          ...              ...              ...
# 8517           FDF53       20.750              reg         0.083607
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 2                   Meat  141.6180            OUT049
# 4              Household   53.8614            OUT013
# 6            Snack Foods   57.6588            OUT013
# 8           Frozen Foods   96.9726            OUT045
# ...                  ...       ...               ...
# 8517        Frozen Foods  178.8318            OUT046
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 2                          1999      Medium               Tier 1
# 4                          1987        High               Tier 3
# 6                          1987        High               Tier 3
# 8                          2002         NaN               Tier 2
# ...                         ...         ...                  ...
# 8517                       1997       Small               Tier 1
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# 8520                       2004       Small               Tier 2
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 2     Supermarket Type1          2097.2700
# 4     Supermarket Type1           994.7052
# 6     Supermarket Type1           343.5528
# 8     Supermarket Type1          1076.5986
# ...                 ...                ...
# 8517  Supermarket Type1          3608.6360
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8522  Supermarket Type1           765.6700
#
# [5577 rows x 12 columns]

# %%
SM1.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1855
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
SM1['Outlet_Size'].value_counts()
# Out:
# Small     1860
# High       932
# Medium     930
# Name: Outlet_Size, dtype: int64

# %%
train['Outlet_Size'].value_counts()
# Out:
# Small     2943
# Medium    2793
# High       932
# Name: Outlet_Size, dtype: int64

# %%
train.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1855
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
test.loc[test['Outlet_Type']=='Grocery Store','Outlet_Size'] = 'Small'

# %%
test['Outlet_Size'].value_counts()
# Out:
# Small     1962
# Medium    1862
# High       621
# Name: Outlet_Size, dtype: int64

# %%
test['Outlet_Size'].fillna(test['Outlet_Size'].mode()[0], inplace=True)
test['Outlet_Size'].value_counts()
# Out:
# Small     3198
# Medium    1862
# High       621
# Name: Outlet_Size, dtype: int64

# %%
test['Item_Weight'].fillna((test['Item_Weight'].mean()), inplace=True)
test.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %%
for i in train.columns:
    print(train[i].value_counts())
    print('\n')
# Out:
# FDW13    10
# FDG33    10
# NCY18     9
# FDD38     9
# DRE49     9
#          ..
# FDY43     1
# FDQ60     1
# FDO33     1
# DRF48     1
# FDC23     1
# Name: Item_Identifier, Length: 1559, dtype: int64
#
#
# 12.857645    1463
# 12.150000      86
# 17.600000      82
# 13.650000      77
# 11.800000      76
#              ...
# 7.275000        2
# 7.685000        1
# 9.420000        1
# 6.520000        1
# 5.400000        1
# Name: Item_Weight, Length: 416, dtype: int64
#
#
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64
#
#
# 0.000000    526
# 0.076975      3
# 0.162462      2
# 0.076841      2
# 0.073562      2
#            ...
# 0.013957      1
# 0.110460      1
# 0.124646      1
# 0.054142      1
# 0.044878      1
# Name: Item_Visibility, Length: 7880, dtype: int64
#
#
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64
#
#
# 172.0422    7
# 170.5422    6
# 196.5084    6
# 188.1872    6
# 142.0154    6
#            ..
# 97.3384     1
# 83.1934     1
# 96.6752     1
# 152.6682    1
# 75.4670     1
# Name: Item_MRP, Length: 5938, dtype: int64
#
#
# OUT027    935
# OUT013    932
# OUT049    930
# OUT046    930
# OUT035    930
# OUT045    929
# OUT018    928
# OUT017    926
# OUT010    555
# OUT019    528
# Name: Outlet_Identifier, dtype: int64
#
#
# 1985    1463
# 1987     932
# 1999     930
# 1997     930
# 2004     930
# 2002     929
# 2009     928
# 2007     926
# 1998     555
# Name: Outlet_Establishment_Year, dtype: int64
#
#
# Small     2943
# Medium    2793
# High       932
# Name: Outlet_Size, dtype: int64
#
#
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: Outlet_Location_Type, dtype: int64
#
#
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64
#
#
# 958.7520     17
# 1342.2528    16
# 703.0848     15
# 1845.5976    15
# 1278.3360    14
#              ..
# 4124.6310     1
# 6622.7126     1
# 1614.5650     1
# 5602.7070     1
# 2778.3834     1
# Name: Item_Outlet_Sales, Length: 3493, dtype: int64

# %%
test['Item_Fat_Content'] = test['Item_Fat_Content'].replace({'LF': 'Low Fat', 'reg':'Regular','low fat':'Low Fat'})
train['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
test['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    3668
# Regular    2013
# Name: Item_Fat_Content, dtype: int64

# %%
train['Item_Identifier'] = train['Item_Identifier'].astype(str).str[:2]
test['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    3668
# Regular    2013
# Name: Item_Fat_Content, dtype: int64

# %%
train['Item_Identifier'] = train['Item_Identifier'].astype(str).str[:2]
train['Item_Identifier'].value_counts()
# Out:
# FD    6125
# NC    1599
# DR     799
# Name: Item_Identifier, dtype: int64

# %%
test['Item_Identifier'] = test['Item_Identifier'].astype(str).str[:2]
test['Item_Identifier'].value_counts()
# Out:
# FD    4076
# NC    1087
# DR     518
# Name: Item_Identifier, dtype: int64

# %%
sns.countplot(y='Item_Type',data=train)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Item_Type'>

# %%
sns.countplot(x='Outlet_Size',data=train)
# Out:
# <AxesSubplot:xlabel='Outlet_Size', ylabel='count'>

# %%
sns.countplot(x='Outlet_Type',data=train)
# Out:
# <AxesSubplot:xlabel='Outlet_Type', ylabel='count'>

# %%
sns.countplot(x='Outlet_Identifier',data=train)
# Out:
# <AxesSubplot:xlabel='Outlet_Identifier', ylabel='count'>

# %%
sns.countplot(x='Outlet_Location_Type',data=train)
# Out:
# <AxesSubplot:xlabel='Outlet_Location_Type', ylabel='count'>

# %%
df = train.copy()

# %%
df.groupby(['Outlet_Type','Outlet_Identifier']).agg({'Item_Outlet_Sales':np.mean}).plot.bar()
X=plt.gca().xaxis

# %%
df.groupby(['Outlet_Type','Outlet_Size']).agg({'Item_Outlet_Sales':np.mean}).plot.bar()
X=plt.gca().xaxis

# %%
df.groupby(['Item_Fat_Content','Outlet_Size']).agg({'Item_Outlet_Sales':np.mean}).plot.bar()
X=plt.gca().xaxis

# %%
df.groupby(['Outlet_Type','Outlet_Location_Type']).agg({'Item_Outlet_Sales':np.mean}).plot.bar()
X=plt.gca().xaxis

# %%
df.groupby(['Outlet_Size','Outlet_Location_Type']).agg({'Item_Outlet_Sales':np.mean}).plot.bar()
X=plt.gca().xaxis

# %%
plt.scatter('Outlet_Type','Item_Outlet_Sales',data=df)

# %%
plt.scatter('Item_Type','Item_Outlet_Sales',data=df)

# %%
sns.pairplot(data=df)

# %%
corr=df.corr()
plt.figure(figsize=(8,8))
sns.heatmap(train.corr(),annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
df.skew()
# Out:
# Item_Weight                  0.090561
# Item_Visibility              1.167091
# Item_MRP                     0.127202
# Outlet_Establishment_Year   -0.396641
# Item_Outlet_Sales            1.177531
# dtype: float64

# %%
df['Item_Visibility']=np.sqrt(df['Item_Visibility'])
df.skew()
# Out:
# Item_Weight                  0.090561
# Item_Visibility             -0.098056
# Item_MRP                     0.127202
# Outlet_Establishment_Year   -0.396641
# Item_Outlet_Sales            1.177531
# dtype: float64

# %%
columns=['Item_Weight','Item_Visibility','Item_MRP','Outlet_Establishment_Year']

# %%
for i in columns:
    sns.distplot(df[i])
    plt.show()

# %%
for i in columns:
    sns.boxplot(df[i])
    plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6668 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
Object=['Item_Identifier','Item_Fat_Content','Item_Type','Outlet_Identifier','Outlet_Size','Outlet_Location_Type','Outlet_Type']

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for i in Object:
    df[i]=le.fit_transform(df[i])

# %%
df
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                   1        9.300                 1         0.126678
# 1                   0        5.920                 2         0.138846
# 2                   1       17.500                 1         0.129461
# 3                   1       19.200                 2         0.000000
# 4                   2        8.930                 1         0.000000
# ...               ...          ...               ...              ...
# 8518                1        6.865                 1         0.238293
# 8519                1        8.380                 2         0.216754
# 8520                2       10.600                 1         0.187580
# 8521                1        7.210                 2         0.381078
# 8522                0       14.800                 1         0.211845
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# 0             4  249.8092                  9                       1999
# 1            14   48.2692                  3                       2009
# 2            10  141.6180                  9                       1999
# 3             6  182.0950                  0                       1998
# 4             9   53.8614                  1                       1987
# ...         ...       ...                ...                        ...
# 8518         13  214.5218                  1                       1987
# 8519          0  108.1570                  7                       2002
# 8520          8   85.1224                  6                       2004
# 8521         13  103.1332                  3                       2009
# 8522         14   75.4670                  8                       1997
#
#       Outlet_Size  Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# 0               1                     0            1          3735.1380
# 1               1                     2            2           443.4228
# 2               1                     0            1          2097.2700
# 3               2                     2            0           732.3800
# 4               0                     2            1           994.7052
# ...           ...                   ...          ...                ...
# 8518            0                     2            1          2778.3834
# 8519            3                     1            1           549.2850
# 8520            2                     1            1          1193.1136
# 8521            1                     2            2          1845.5976
# 8522            2                     0            1           765.6700
#
# [8523 rows x 12 columns]

# %%
df_x=df.drop(columns='Item_Outlet_Sales')
y=df['Item_Outlet_Sales']

# %%
df_x
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                   1        9.300                 1         0.126678
# 1                   0        5.920                 2         0.138846
# 2                   1       17.500                 1         0.129461
# 3                   1       19.200                 2         0.000000
# 4                   2        8.930                 1         0.000000
# ...               ...          ...               ...              ...
# 8518                1        6.865                 1         0.238293
# 8519                1        8.380                 2         0.216754
# 8520                2       10.600                 1         0.187580
# 8521                1        7.210                 2         0.381078
# 8522                0       14.800                 1         0.211845
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# 0             4  249.8092                  9                       1999
# 1            14   48.2692                  3                       2009
# 2            10  141.6180                  9                       1999
# 3             6  182.0950                  0                       1998
# 4             9   53.8614                  1                       1987
# ...         ...       ...                ...                        ...
# 8518         13  214.5218                  1                       1987
# 8519          0  108.1570                  7                       2002
# 8520          8   85.1224                  6                       2004
# 8521         13  103.1332                  3                       2009
# 8522         14   75.4670                  8                       1997
#
#       Outlet_Size  Outlet_Location_Type  Outlet_Type
# 0               1                     0            1
# 1               1                     2            2
# 2               1                     0            1
# 3               2                     2            0
# 4               0                     2            1
# ...           ...                   ...          ...
# 8518            0                     2            1
# 8519            3                     1            1
# 8520            2                     1            1
# 8521            1                     2            2
# 8522            2                     0            1
#
# [8523 rows x 11 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc_x=sc.fit_transform(df_x)

# %%
sc_x
# Out:
# array([[-0.17979501, -0.84187169, -0.57284357, ..., -0.71772335,
#         -1.36933384, -0.25265831],
#        [-2.09528612, -1.64170589,  0.97809218, ..., -0.71772335,
#          1.09156913,  1.00297245],
#        [-0.17979501,  1.09855449, -0.57284357, ..., -0.71772335,
#         -1.36933384, -0.25265831],
#        ...,
#        [ 1.73569609, -0.53424315, -0.57284357, ...,  0.35152261,
#         -0.13888236, -0.25265831],
#        [-0.17979501, -1.33644372,  0.97809218, ..., -0.71772335,
#          1.09156913,  1.00297245],
#        [-2.09528612,  0.45963367, -0.57284357, ...,  0.35152261,
#         -1.36933384, -0.25265831]])

# %%
x=sc_x

# %%
x=pd.DataFrame(x,columns=df_x.columns)

# %%
x
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0           -0.179795    -0.841872         -0.572844        -0.997548
# 1           -2.095286    -1.641706          0.978092        -0.884139
# 2           -0.179795     1.098554         -0.572844        -0.971612
# 3           -0.179795     1.500838          0.978092        -2.178206
# 4            1.735696    -0.929428         -0.572844        -2.178206
# ...               ...          ...               ...              ...
# 8518        -0.179795    -1.418084         -0.572844         0.042719
# 8519        -0.179795    -1.059578          0.978092        -0.158022
# 8520         1.735696    -0.534243         -0.572844        -0.429930
# 8521        -0.179795    -1.336444          0.978092         1.373504
# 8522        -2.095286     0.459634         -0.572844        -0.203778
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# 0     -0.766479  1.747454           1.507813                   0.139541
# 1      1.608963 -1.489023          -0.607071                   1.334103
# 2      0.658786  0.010040           1.507813                   0.139541
# 3     -0.291391  0.660050          -1.664513                   0.020085
# 4      0.421242 -1.399220          -1.312032                  -1.293934
# ...         ...       ...                ...                        ...
# 8518   1.371418  1.180783          -1.312032                  -1.293934
# 8519  -1.716656 -0.527301           0.802852                   0.497909
# 8520   0.183698 -0.897208           0.450371                   0.736822
# 8521   1.371418 -0.607977          -0.607071                   1.334103
# 8522   1.608963 -1.052261           1.155333                  -0.099372
#
#       Outlet_Size  Outlet_Location_Type  Outlet_Type
# 0       -0.717723             -1.369334    -0.252658
# 1       -0.717723              1.091569     1.002972
# 2       -0.717723             -1.369334    -0.252658
# 3        0.351523              1.091569    -1.508289
# 4       -1.786969              1.091569    -0.252658
# ...           ...                   ...          ...
# 8518    -1.786969              1.091569    -0.252658
# 8519     1.420769             -0.138882    -0.252658
# 8520     0.351523             -0.138882    -0.252658
# 8521    -0.717723              1.091569     1.002972
# 8522     0.351523             -1.369334    -0.252658
#
# [8523 rows x 11 columns]

# %%
# Model Fitting
# Importing the required libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f'At random state {i},the training accuracy is: {r2_score(y_train,pred_train)}')
    print(f'At random state {i},the testing accuracy is: {r2_score(y_test,pred_test)}')
    print('\n')
# Out:
# At random state 0,the training accuracy is: 0.5010301508271413
# At random state 0,the testing accuracy is: 0.503503504987395
#
#
# At random state 1,the training accuracy is: 0.5025648130411413
# At random state 1,the testing accuracy is: 0.49690775844655233
#
#
# At random state 2,the training accuracy is: 0.5056414779203657
# At random state 2,the testing accuracy is: 0.48502564663601977
#
#
# At random state 3,the training accuracy is: 0.4928005529558167
# At random state 3,the testing accuracy is: 0.5353455662297197
#
#
# At random state 4,the training accuracy is: 0.5039153183903233
# At random state 4,the testing accuracy is: 0.48982147751163074
#
#
# At random state 5,the training accuracy is: 0.5036586896446531
# At random state 5,the testing accuracy is: 0.4928067377365275
#
#
# At random state 6,the training accuracy is: 0.5018869921310989
# At random state 6,the testing accuracy is: 0.49916977861806744
#
#
# At random state 7,the training accuracy is: 0.5054469273417959
# At random state 7,the testing accuracy is: 0.4868611835855632
#
#
# At random state 8,the training accuracy is: 0.4983281211568209
# At random state 8,the testing accuracy is: 0.5123814938893905
#
#
# At random state 9,the training accuracy is: 0.5026663282008883
# At random state 9,the testing accuracy is: 0.4968231957334803
#
#
# At random state 10,the training accuracy is: 0.4983339615682655
# At random state 10,the testing accuracy is: 0.5138051555120813
#
#
# At random state 11,the training accuracy is: 0.507685110753871
# At random state 11,the testing accuracy is: 0.4762690278033609
#
#
# At random state 12,the training accuracy is: 0.49874445720579164
# At random state 12,the testing accuracy is: 0.5125210625170806
#
#
# At random state 13,the training accuracy is: 0.5028525896638443
# At random state 13,the testing accuracy is: 0.4956378451519887
#
#
# At random state 14,the training accuracy is: 0.5011166553699007
# At random state 14,the testing accuracy is: 0.5034264558019489
#
#
# At random state 15,the training accuracy is: 0.4976147833010238
# At random state 15,the testing accuracy is: 0.5145150913997965
#
#
# At random state 16,the training accuracy is: 0.5022502094142391
# At random state 16,the testing accuracy is: 0.49700887809561567
#
#
# At random state 17,the training accuracy is: 0.49994989245149524
# At random state 17,the testing accuracy is: 0.5078487921942401
#
#
# At random state 18,the training accuracy is: 0.5028358790253384
# At random state 18,the testing accuracy is: 0.49633614385466707
#
#
# At random state 19,the training accuracy is: 0.5035160682434396
# At random state 19,the testing accuracy is: 0.4935508265464781
#
#
# At random state 20,the training accuracy is: 0.4993781754079081
# At random state 20,the testing accuracy is: 0.5096336294926027
#
#
# At random state 21,the training accuracy is: 0.4998739268721327
# At random state 21,the testing accuracy is: 0.5084058170678734
#
#
# At random state 22,the training accuracy is: 0.5044930425121819
# At random state 22,the testing accuracy is: 0.4900094114043354
#
#
# At random state 23,the training accuracy is: 0.5031518968960849
# At random state 23,the testing accuracy is: 0.49427176897157465
#
#
# At random state 24,the training accuracy is: 0.5056345632162267
# At random state 24,the testing accuracy is: 0.48365227067717487
#
#
# At random state 25,the training accuracy is: 0.5048711842739664
# At random state 25,the testing accuracy is: 0.4885524803267087
#
#
# At random state 26,the training accuracy is: 0.49794075974434737
# At random state 26,the testing accuracy is: 0.5146117072501091
#
#
# At random state 27,the training accuracy is: 0.5043255124362513
# At random state 27,the testing accuracy is: 0.49029150334415017
#
#
# At random state 28,the training accuracy is: 0.4977279788814174
# At random state 28,the testing accuracy is: 0.5160454525829233
#
#
# At random state 29,the training accuracy is: 0.5041914492588864
# At random state 29,the testing accuracy is: 0.49041537000173907
#
#
# At random state 30,the training accuracy is: 0.5040144203417692
# At random state 30,the testing accuracy is: 0.4920247000962329
#
#
# At random state 31,the training accuracy is: 0.4978834881844878
# At random state 31,the testing accuracy is: 0.5158871723722326
#
#
# At random state 32,the training accuracy is: 0.502313834119543
# At random state 32,the testing accuracy is: 0.4977313478722364
#
#
# At random state 33,the training accuracy is: 0.5015379489595164
# At random state 33,the testing accuracy is: 0.5003815758180961
#
#
# At random state 34,the training accuracy is: 0.5031017884577458
# At random state 34,the testing accuracy is: 0.4942275678128256
#
#
# At random state 35,the training accuracy is: 0.5041892002470624
# At random state 35,the testing accuracy is: 0.4906697006056663
#
#
# At random state 36,the training accuracy is: 0.5057377398924718
# At random state 36,the testing accuracy is: 0.481421553038177
#
#
# At random state 37,the training accuracy is: 0.5079461630722734
# At random state 37,the testing accuracy is: 0.4730103963610863
#
#
# At random state 38,the training accuracy is: 0.5084373632774297
# At random state 38,the testing accuracy is: 0.47325468648197155
#
#
# At random state 39,the training accuracy is: 0.4974795636138025
# At random state 39,the testing accuracy is: 0.5165098077931314
#
#
# At random state 40,the training accuracy is: 0.4995426228140667
# At random state 40,the testing accuracy is: 0.508187079210286
#
#
# At random state 41,the training accuracy is: 0.5092748997800824
# At random state 41,the testing accuracy is: 0.4712940159482123
#
#
# At random state 42,the training accuracy is: 0.49686463495725486
# At random state 42,the testing accuracy is: 0.5200902082195809
#
#
# At random state 43,the training accuracy is: 0.5033888427038228
# At random state 43,the testing accuracy is: 0.4922538154503796
#
#
# At random state 44,the training accuracy is: 0.4996789637198221
# At random state 44,the testing accuracy is: 0.5085559272437681
#
#
# At random state 45,the training accuracy is: 0.5001753803644097
# At random state 45,the testing accuracy is: 0.5061069843271768
#
#
# At random state 46,the training accuracy is: 0.5042632841832936
# At random state 46,the testing accuracy is: 0.4895481648486524
#
#
# At random state 47,the training accuracy is: 0.5031949070003754
# At random state 47,the testing accuracy is: 0.4945925695594049
#
#
# At random state 48,the training accuracy is: 0.5016421487182579
# At random state 48,the testing accuracy is: 0.5004379747906145
#
#
# At random state 49,the training accuracy is: 0.4996130680846066
# At random state 49,the testing accuracy is: 0.5081253855842933
#
#
# At random state 50,the training accuracy is: 0.5008464666805847
# At random state 50,the testing accuracy is: 0.5042667328160093
#
#
# At random state 51,the training accuracy is: 0.5087724921164687
# At random state 51,the testing accuracy is: 0.47099156941863796
#
#
# At random state 52,the training accuracy is: 0.5031890207755312
# At random state 52,the testing accuracy is: 0.49410377118355553
#
#
# At random state 53,the training accuracy is: 0.5019203282166028
# At random state 53,the testing accuracy is: 0.4991606643346431
#
#
# At random state 54,the training accuracy is: 0.49674628143433086
# At random state 54,the testing accuracy is: 0.5186334201929153
#
#
# At random state 55,the training accuracy is: 0.5040962978197103
# At random state 55,the testing accuracy is: 0.4909635146342749
#
#
# At random state 56,the training accuracy is: 0.5090515152438315
# At random state 56,the testing accuracy is: 0.47313134517474065
#
#
# At random state 57,the training accuracy is: 0.5031721709185679
# At random state 57,the testing accuracy is: 0.49421432839752266
#
#
# At random state 58,the training accuracy is: 0.5043703311624018
# At random state 58,the testing accuracy is: 0.48860622768665996
#
#
# At random state 59,the training accuracy is: 0.5024649725797398
# At random state 59,the testing accuracy is: 0.4967315778811471
#
#
# At random state 60,the training accuracy is: 0.5000859345025832
# At random state 60,the testing accuracy is: 0.5063951023491902
#
#
# At random state 61,the training accuracy is: 0.5083363408997426
# At random state 61,the testing accuracy is: 0.4721655752482762
#
#
# At random state 62,the training accuracy is: 0.4969465831121256
# At random state 62,the testing accuracy is: 0.5186823773542996
#
#
# At random state 63,the training accuracy is: 0.49595263374779786
# At random state 63,the testing accuracy is: 0.5243821880631996
#
#
# At random state 64,the training accuracy is: 0.5056842182068297
# At random state 64,the testing accuracy is: 0.48425625582827014
#
#
# At random state 65,the training accuracy is: 0.5002774194557107
# At random state 65,the testing accuracy is: 0.5053663358473033
#
#
# At random state 66,the training accuracy is: 0.5029388514544133
# At random state 66,the testing accuracy is: 0.4960814895863551
#
#
# At random state 67,the training accuracy is: 0.49961948012212476
# At random state 67,the testing accuracy is: 0.5082724597860014
#
#
# At random state 68,the training accuracy is: 0.49849133562607284
# At random state 68,the testing accuracy is: 0.5130052360474082
#
#
# At random state 69,the training accuracy is: 0.5021934346271011
# At random state 69,the testing accuracy is: 0.49825455514690287
#
#
# At random state 70,the training accuracy is: 0.4982925626515382
# At random state 70,the testing accuracy is: 0.5139622598366038
#
#
# At random state 71,the training accuracy is: 0.5023909194792135
# At random state 71,the testing accuracy is: 0.49724913000012716
#
#
# At random state 72,the training accuracy is: 0.49839955006436343
# At random state 72,the testing accuracy is: 0.5138489882442089
#
#
# At random state 73,the training accuracy is: 0.5031772868938671
# At random state 73,the testing accuracy is: 0.49409863341629146
#
#
# At random state 74,the training accuracy is: 0.5071174124150033
# At random state 74,the testing accuracy is: 0.4772642673215628
#
#
# At random state 75,the training accuracy is: 0.5000012372406287
# At random state 75,the testing accuracy is: 0.5073158583648063
#
#
# At random state 76,the training accuracy is: 0.4947333086018233
# At random state 76,the testing accuracy is: 0.5287814323240481
#
#
# At random state 77,the training accuracy is: 0.5022766891884645
# At random state 77,the testing accuracy is: 0.4981325143762504
#
#
# At random state 78,the training accuracy is: 0.5045948468445722
# At random state 78,the testing accuracy is: 0.4886386133306857
#
#
# At random state 79,the training accuracy is: 0.4973762209793946
# At random state 79,the testing accuracy is: 0.5169867150330278
#
#
# At random state 80,the training accuracy is: 0.4969340757578333
# At random state 80,the testing accuracy is: 0.5201188041826925
#
#
# At random state 81,the training accuracy is: 0.5011569478547109
# At random state 81,the testing accuracy is: 0.502983238853286
#
#
# At random state 82,the training accuracy is: 0.4992312067144782
# At random state 82,the testing accuracy is: 0.5100752984155843
#
#
# At random state 83,the training accuracy is: 0.5040202843811856
# At random state 83,the testing accuracy is: 0.4901323060005959
#
#
# At random state 84,the training accuracy is: 0.5017027236028977
# At random state 84,the testing accuracy is: 0.49955083873912454
#
#
# At random state 85,the training accuracy is: 0.5005150760400632
# At random state 85,the testing accuracy is: 0.5050321630129802
#
#
# At random state 86,the training accuracy is: 0.5016135037059795
# At random state 86,the testing accuracy is: 0.5006535895492391
#
#
# At random state 87,the training accuracy is: 0.50329831334771
# At random state 87,the testing accuracy is: 0.4932199938467928
#
#
# At random state 88,the training accuracy is: 0.49784184231416284
# At random state 88,the testing accuracy is: 0.5166836962846192
#
#
# At random state 89,the training accuracy is: 0.4968470353056005
# At random state 89,the testing accuracy is: 0.5194345942116454
#
#
# At random state 90,the training accuracy is: 0.5097883094323163
# At random state 90,the testing accuracy is: 0.46447479536710334
#
#
# At random state 91,the training accuracy is: 0.5091267313088076
# At random state 91,the testing accuracy is: 0.4701072159550187
#
#
# At random state 92,the training accuracy is: 0.5007381390897335
# At random state 92,the testing accuracy is: 0.5036215816896821
#
#
# At random state 93,the training accuracy is: 0.5002495141436052
# At random state 93,the testing accuracy is: 0.5060285086821973
#
#
# At random state 94,the training accuracy is: 0.5013226144070111
# At random state 94,the testing accuracy is: 0.5003122708876332
#
#
# At random state 95,the training accuracy is: 0.5009252937637791
# At random state 95,the testing accuracy is: 0.503733991547199
#
#
# At random state 96,the training accuracy is: 0.5055034888307737
# At random state 96,the testing accuracy is: 0.48187315906452555
#
#
# At random state 97,the training accuracy is: 0.5016062519310485
# At random state 97,the testing accuracy is: 0.4995990104524273
#
#
# At random state 98,the training accuracy is: 0.5066129044418728
# At random state 98,the testing accuracy is: 0.4788412671380743
#
#
# At random state 99,the training accuracy is: 0.497367219559256
# At random state 99,the testing accuracy is: 0.5158926152056276

# %%
# Fitting the data to SupportVectorRegression model
from sklearn.svm import SVR
kernellist=['linear','poly','rbf']
for i in kernellist:
    sv=SVR(kernel=i)
    sv.fit(x_train,y_train)
    print(sv.score(x_train,y_train))
# Out:
# 0.458181410667133
# 0.07037269213034059
# 0.05399897330375181

# %%
#Fitting the data to various model and checking the accuracy
sv=SVR(kernel='linear')
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor

dt=DecisionTreeRegressor()
rf=RandomForestRegressor()
ab=AdaBoostRegressor()

model=[lr,sv,dt,rf,ab]

for m in model:
    m.fit(x_train,y_train)
    pred_train=m.predict(x_train)
    pred_test=m.predict(x_test)
    train_score=r2_score(y_train,pred_train)
    test_score=r2_score(y_test,pred_test)
    print('Accuracy of', m )
    print('Training Score', train_score)
    print('Testing Score', test_score)
    print('\n')
# Out:
# Accuracy of LinearRegression()
# Training Score 0.497367219559256
# Testing Score 0.5158926152056276
#
#
# Accuracy of SVR(kernel='linear')
# Training Score 0.458181410667133
# Testing Score 0.4638996394596824
#
#
# Accuracy of DecisionTreeRegressor()
# Training Score 1.0
# Testing Score 0.24595167921217986
#
#
# Accuracy of RandomForestRegressor()
# Training Score 0.9361730796766464
# Testing Score 0.5776697157859948
#
#
# Accuracy of AdaBoostRegressor()
# Training Score 0.5139087020397658
# Testing Score 0.5211605944419377

# %%
#Cross Validation
from sklearn.model_selection import cross_val_score

# %%
model=(lr,sv,dt,rf,ab)
for m in model:
    score=cross_val_score(m,x,y,cv=5)
    print('Mean Accuracy of', m)
    print(score.mean())
    print('\n')
# Out:
# Mean Accuracy of LinearRegression()
# 0.49947271425004247
#
#
# Mean Accuracy of SVR(kernel='linear')
# 0.46134106509550765
#
#
# Mean Accuracy of DecisionTreeRegressor()
# 0.1404569480936834
#
#
# Mean Accuracy of RandomForestRegressor()
# 0.5519195568431173
#
#
# Mean Accuracy of AdaBoostRegressor()
# 0.4862010116365029

# %%
# Normalization and HyperTuning
# Importing the required libraries for normalizing the coefficients and Hypertuning our model
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso

# %%
parameters={'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 1, 'random_state': 0}

# %%
ls=Lasso(alpha=10,random_state=0)
ls.fit(x_train,y_train)
pred_ls=ls.predict(x_test)
lss=r2_score(y_test,pred_ls)
lss
# Out:
# 0.515302381107972

# %%
cv_score=cross_val_score(ls,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.49936906290416533

# %%
Finalmod=LinearRegression(copy_X=True, fit_intercept= True, n_jobs=None, normalize=False)
Finalmod.fit(x_train,y_train)
pred_final=Finalmod.predict(x_test)
rfs=r2_score(y_test,pred_final)
print('R2 Score', rfs*100)

rfscore=cross_val_score(Finalmod,x,y,cv=5)
rfc=rfscore.mean()
print('Cross Val score', rfc*100)
# Out:
# R2 Score 51.58926152056276
# Cross Val score 49.947271425004246

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_final,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('Actual Sales',fontsize=14)
plt.ylabel('Predicted Sales',fontsize=14)
plt.title('Linear Regression',fontsize=18)
plt.show()

# %%
import joblib
joblib.dump(Finalmod,'BigDataMart_sales.obj')
# Out:
# ['BigDataMart_sales.obj']

# %%
loaded_model=joblib.load('BigDataMart_sales.obj')
test
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0                 FD    20.750000          Low Fat         0.007565
# 1                 FD     8.300000          Regular         0.038428
# 2                 NC    14.600000          Low Fat         0.099575
# 3                 FD     7.315000          Low Fat         0.015388
# 4                 FD    12.695633          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676              FD    10.500000          Regular         0.013496
# 5677              FD     7.600000          Regular         0.142991
# 5678              NC    10.000000          Low Fat         0.073529
# 5679              FD    15.300000          Regular         0.000000
# 5680              FD     9.500000          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# 1                  Dairy   87.3198            OUT017
# 2                 Others  241.7538            OUT010
# 3            Snack Foods  155.0340            OUT017
# 4                  Dairy  234.2300            OUT027
# ...                  ...       ...               ...
# 5676         Snack Foods  141.3154            OUT046
# 5677       Starchy Foods  169.1448            OUT018
# 5678  Health and Hygiene  118.7440            OUT045
# 5679              Canned  214.6218            OUT017
# 5680              Canned   79.7960            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2007       Small               Tier 2
# 2                          1998       Small               Tier 3
# 3                          2007       Small               Tier 2
# 4                          1985      Medium               Tier 3
# ...                         ...         ...                  ...
# 5676                       1997       Small               Tier 1
# 5677                       2009      Medium               Tier 3
# 5678                       2002       Small               Tier 2
# 5679                       2007       Small               Tier 2
# 5680                       2002       Small               Tier 2
#
#             Outlet_Type
# 0     Supermarket Type1
# 1     Supermarket Type1
# 2         Grocery Store
# 3     Supermarket Type1
# 4     Supermarket Type3
# ...                 ...
# 5676  Supermarket Type1
# 5677  Supermarket Type2
# 5678  Supermarket Type1
# 5679  Supermarket Type1
# 5680  Supermarket Type1
#
# [5681 rows x 11 columns]

# %%
Object_test=['Item_Identifier','Item_Fat_Content','Item_Type','Outlet_Identifier','Outlet_Size','Outlet_Location_Type','Outlet_Type']

# %%
for i in Object_test:
    test[i]=le.fit_transform(test[i])

# %%
sc_test=sc.fit_transform(test)

# %%
X=sc_test

# %%
X=pd.DataFrame(X,columns=test.columns)

# %%
x
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0           -0.179795    -0.841872         -0.572844        -0.997548
# 1           -2.095286    -1.641706          0.978092        -0.884139
# 2           -0.179795     1.098554         -0.572844        -0.971612
# 3           -0.179795     1.500838          0.978092        -2.178206
# 4            1.735696    -0.929428         -0.572844        -2.178206
# ...               ...          ...               ...              ...
# 8518        -0.179795    -1.418084         -0.572844         0.042719
# 8519        -0.179795    -1.059578          0.978092        -0.158022
# 8520         1.735696    -0.534243         -0.572844        -0.429930
# 8521        -0.179795    -1.336444          0.978092         1.373504
# 8522        -2.095286     0.459634         -0.572844        -0.203778
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# 0     -0.766479  1.747454           1.507813                   0.139541
# 1      1.608963 -1.489023          -0.607071                   1.334103
# 2      0.658786  0.010040           1.507813                   0.139541
# 3     -0.291391  0.660050          -1.664513                   0.020085
# 4      0.421242 -1.399220          -1.312032                  -1.293934
# ...         ...       ...                ...                        ...
# 8518   1.371418  1.180783          -1.312032                  -1.293934
# 8519  -1.716656 -0.527301           0.802852                   0.497909
# 8520   0.183698 -0.897208           0.450371                   0.736822
# 8521   1.371418 -0.607977          -0.607071                   1.334103
# 8522   1.608963 -1.052261           1.155333                  -0.099372
#
#       Outlet_Size  Outlet_Location_Type  Outlet_Type
# 0       -0.717723             -1.369334    -0.252658
# 1       -0.717723              1.091569     1.002972
# 2       -0.717723             -1.369334    -0.252658
# 3        0.351523              1.091569    -1.508289
# 4       -1.786969              1.091569    -0.252658
# ...           ...                   ...          ...
# 8518    -1.786969              1.091569    -0.252658
# 8519     1.420769             -0.138882    -0.252658
# 8520     0.351523             -0.138882    -0.252658
# 8521    -0.717723              1.091569     1.002972
# 8522     0.351523             -1.369334    -0.252658
#
# [8523 rows x 11 columns]

# %%
Test_pred=loaded_model.predict(X)

# %%
Test=pd.DataFrame(data=Test_pred)
Test
# Out:
#                 0
# 0     1829.309722
# 1     1042.439826
# 2     2344.805964
# 3     2066.432699
# 4     5149.115479
# ...           ...
# 5676  2391.146319
# 5677  2964.584107
# 5678  1775.314629
# 5679  3082.143669
# 5680  1202.471975
#
# [5681 rows x 1 columns]

# %%
Test_final1=test.join(Test)
Test_final1
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                   1    20.750000                 0         0.007565
# 1                   1     8.300000                 1         0.038428
# 2                   2    14.600000                 0         0.099575
# 3                   1     7.315000                 0         0.015388
# 4                   1    12.695633                 1         0.118599
# ...               ...          ...               ...              ...
# 5676                1    10.500000                 1         0.013496
# 5677                1     7.600000                 1         0.142991
# 5678                2    10.000000                 0         0.073529
# 5679                1    15.300000                 1         0.000000
# 5680                1     9.500000                 1         0.104720
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# 0            13  107.8622                  9                       1999
# 1             4   87.3198                  2                       2007
# 2            11  241.7538                  0                       1998
# 3            13  155.0340                  2                       2007
# 4             4  234.2300                  5                       1985
# ...         ...       ...                ...                        ...
# 5676         13  141.3154                  8                       1997
# 5677         15  169.1448                  3                       2009
# 5678          8  118.7440                  7                       2002
# 5679          3  214.6218                  2                       2007
# 5680          3   79.7960                  7                       2002
#
#       Outlet_Size  Outlet_Location_Type  Outlet_Type            0
# 0               1                     0            1  1829.309722
# 1               2                     1            1  1042.439826
# 2               2                     2            0  2344.805964
# 3               2                     1            1  2066.432699
# 4               1                     2            3  5149.115479
# ...           ...                   ...          ...          ...
# 5676            2                     0            1  2391.146319
# 5677            1                     2            2  2964.584107
# 5678            2                     1            1  1775.314629
# 5679            2                     1            1  3082.143669
# 5680            2                     1            1  1202.471975
#
# [5681 rows x 12 columns]

# %%
Test_final1.rename(columns={0: 'Item_Outlet_Sales'}, inplace=True)

# %%
Test_final1
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                   1    20.750000                 0         0.007565
# 1                   1     8.300000                 1         0.038428
# 2                   2    14.600000                 0         0.099575
# 3                   1     7.315000                 0         0.015388
# 4                   1    12.695633                 1         0.118599
# ...               ...          ...               ...              ...
# 5676                1    10.500000                 1         0.013496
# 5677                1     7.600000                 1         0.142991
# 5678                2    10.000000                 0         0.073529
# 5679                1    15.300000                 1         0.000000
# 5680                1     9.500000                 1         0.104720
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# 0            13  107.8622                  9                       1999
# 1             4   87.3198                  2                       2007
# 2            11  241.7538                  0                       1998
# 3            13  155.0340                  2                       2007
# 4             4  234.2300                  5                       1985
# ...         ...       ...                ...                        ...
# 5676         13  141.3154                  8                       1997
# 5677         15  169.1448                  3                       2009
# 5678          8  118.7440                  7                       2002
# 5679          3  214.6218                  2                       2007
# 5680          3   79.7960                  7                       2002
#
#       Outlet_Size  Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# 0               1                     0            1        1829.309722
# 1               2                     1            1        1042.439826
# 2               2                     2            0        2344.805964
# 3               2                     1            1        2066.432699
# 4               1                     2            3        5149.115479
# ...           ...                   ...          ...                ...
# 5676            2                     0            1        2391.146319
# 5677            1                     2            2        2964.584107
# 5678            2                     1            1        1775.314629
# 5679            2                     1            1        3082.143669
# 5680            2                     1            1        1202.471975
#
# [5681 rows x 12 columns]
